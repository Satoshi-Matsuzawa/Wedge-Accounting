# %%
import pandas as pd

# %%
url = "https://warp.da.ndl.go.jp/info:ndljp/pid/11423429/www.stat.go.jp/data/chouki/zuhyou/20-01-a.xls"
df_original = pd.read_excel(url, header = None, index_col = None)

# %%
stat_name_jpn = df_original.loc[[0,1],0]

# %%
stat_name_eng = df_original.loc[[2,3],0]

# %%
stat_name_jpn, stat_name_eng
# Out:
# (0    ２０－１－ａ　１世帯当たり年平均１か月間の消費支出（全世帯）－　全都市
#  1                            （昭和２１年～３７年）
#  Name: 0, dtype: object,
#  2    20-1-a Annual Average of Monthly Consumption E...
#  3                            - All Cities (1946--1962)
#  Name: 0, dtype: object)

# %%
# remove columns and rows with too many nulls
df_dropped = df_original.loc[df_original.notnull().sum(axis=1) > 2, df_original.notnull().sum() > 2]

# %%
df_picked = df_dropped.iloc[6:, [0, 1, 3, 5, 6]]

# %%
columns = ['year_jpn', 'year_wst', 'hh_size', 'cons_exp', 'food_exp']

# %%
df_picked.columns = columns

# %%
df_picked
# Out:
#    year_jpn year_wst hh_size cons_exp food_exp
# 13      22　     1947     4.7     4684     2952
# 14      23　     1948    4.81     8780     5302
# 15      24　     1949    4.74    11885     7138
# 16      25　     1950    4.79    11980     6880
# 17      26　     1951     4.8    14389     7822
# 18      27　     1952    4.89    17838     9134
# 19      28　     1953    4.92    21381    10374
# 20      29　     1954    4.91    22678    10995
# 21      30　     1955    4.84    23211    10891
# 22      31　     1956    4.61    23958    10786
# 23      32　     1957    4.56    25608    11368
# 24      33　     1958    4.57    27171    11898
# 25      34　     1959    4.56    28902    12260
# 26      35　     1960    4.51    31276    13000
# 27      36　     1961    4.35    34329    13842
# 28      37　     1962    4.29    38587    15063

# %%
url2 = "https://warp.da.ndl.go.jp/info:ndljp/pid/11423429/www.stat.go.jp/data/chouki/zuhyou/20-01-b.xls"
df_original_2 = pd.read_excel(url2, header = None, index_col = None)

# %%
df_original_2
# Out:
#                                                    0    1    2    3    4    \
# 0          ２０－１－ｂ　１世帯当たり年平均１か月間の消費支出（全世帯）－　全国，人口５万以上の市  NaN  NaN  NaN  NaN
# 1                                        （昭和３８年～平成１９年）  NaN  NaN  NaN  NaN
# 2    20-1-b Annual Average of Monthly Consumption E...  NaN  NaN  NaN  NaN
# 3     -All Japan, Cities with Population of 50,000 ...  NaN  NaN  NaN  NaN
# 4                                                  NaN  NaN  NaN  NaN  NaN
# ..                                                 ...  ...  ...  ...  ...
# 106  (1) Non-agricultural, forestry and fisheries h...  NaN  NaN  NaN  NaN
# 107                           〔資料〕 総理府統計局「家計調査年報」（刊行物）  NaN  NaN  NaN  NaN
# 108                           総務省統計局統計調査部消費統計課「家計調査年報」  NaN  NaN  NaN  NaN
# 109  Source:  Statistics Bureau, Prime Minister's O...  NaN  NaN  NaN  NaN
# 110               Statistical Survey Department, St...  NaN  NaN  NaN  NaN
#
# ...

# %%
# remove columns and rows with too many nulls
df_dropped_2 = df_original_2.loc[df_original_2.notnull().sum(axis=1) > 2, df_original_2.notnull().sum() > 2]

# %%
df_dropped_2
# Out:
#                0     1                           2    \
# 7            区分，年次   NaN              世帯数分布\n(抽出率調整)
# 8              NaN   NaN                         NaN
# 9              NaN   NaN                         NaN
# 10             NaN   NaN                         NaN
# 12   Item and year   NaN  Distribution of households
# ..             ...   ...                         ...
# 100           15    2003                        7581
# 101           16    2004                        7589
# 102           17    2005                        7579
# 103           18    2006                        7589
# 104           19    2007                        7607
#
#                               3                                        4    \
# 7                           集計世帯数                                     世帯人員
# 8                             NaN                                      NaN
# 9                             NaN                                      NaN
# ...

# %%
df_picked_2 = df_dropped_2.iloc[5:50, [0, 1, 4, 7, 8]]

# %%
columns = ['year_jpn', 'year_wst', 'hh_size', 'cons_exp', 'food_exp']

# %%
df_picked_2
# Out:
#          0     1     4       7      8
# 14   昭和38年  1963   4.3   40246  15571
# 15     39　  1964  4.29   44481  16932
# 16     40　  1965  4.26   48396  18454
# 17     41　  1966  4.19   52516  19593
# 18     42　  1967  4.15   57071  21004
# 19     43　  1968  4.07   63607  22585
# 20     44　  1969  3.99   70386  24345
# 21   　45    1970  3.98   79531  27092
# 22     46　  1971  3.96   87475  29162
# 23     47　  1972  3.93   96026  31357
# 24     48　  1973  3.91  112116  35789
# 25     49　  1974   3.9  136024  44350
# 26     50　  1975  3.89  157982  50479
# 27     51　  1976  3.84  174790  55308
# 28     52　  1977  3.82  190497  58660
# 29     53　  1978  3.83  201715  60896
# 30     54　  1979  3.83  214697  62769
# 31     55　  1980  3.82  230568  66923
# 32     56　  1981  3.79  240014  69183
# 33     57　  1982  3.78  253169  71342
# 34     58　  1983  3.76  259521  72173
# 35     59　  1984  3.72  266319  72962
# 36     60　  1985  3.71  273114  73735
# 37  　　61    1986  3.69  276374  73995
# ...

# %%
df_picked_2.columns = columns

# %%
df_picked_2
# Out:
#    year_jpn year_wst hh_size cons_exp food_exp
# 14    昭和38年     1963     4.3    40246    15571
# 15      39　     1964    4.29    44481    16932
# 16      40　     1965    4.26    48396    18454
# 17      41　     1966    4.19    52516    19593
# 18      42　     1967    4.15    57071    21004
# 19      43　     1968    4.07    63607    22585
# 20      44　     1969    3.99    70386    24345
# 21    　45       1970    3.98    79531    27092
# 22      46　     1971    3.96    87475    29162
# 23      47　     1972    3.93    96026    31357
# 24      48　     1973    3.91   112116    35789
# 25      49　     1974     3.9   136024    44350
# 26      50　     1975    3.89   157982    50479
# 27      51　     1976    3.84   174790    55308
# 28      52　     1977    3.82   190497    58660
# 29      53　     1978    3.83   201715    60896
# 30      54　     1979    3.83   214697    62769
# 31      55　     1980    3.82   230568    66923
# 32      56　     1981    3.79   240014    69183
# ...

# %%
df = pd.concat([df_picked, df_picked_2])

# %%
df
# Out:
#    year_jpn year_wst hh_size cons_exp food_exp
# 13      22　     1947     4.7     4684     2952
# 14      23　     1948    4.81     8780     5302
# 15      24　     1949    4.74    11885     7138
# 16      25　     1950    4.79    11980     6880
# 17      26　     1951     4.8    14389     7822
# ..      ...      ...     ...      ...      ...
# 54     15       2003    3.21   302623    70260
# 55     16       2004    3.19   304203    70116
# 56     17       2005    3.15   300903    68910
# 57     18       2006    3.12   295332    68178
# 58     19       2007     3.1   297139    68522
#
# [61 rows x 5 columns]

# %%
df.iloc[0,0]
# Out:
# '22\u3000'

# %%
df.loc[14,:]
# Out:
#    year_jpn year_wst hh_size cons_exp food_exp  non_food_exp  cons_exp_pc  \
# 14       23     1948    4.81     8780     5302          3478  1825.363825
# 14    昭和38年     1963     4.3    40246    15571         24675  9359.534884
#
#     food_exp_pc non_food_exp_pc  food_shr
# 14  1102.286902      723.076923  0.603872
# 14  3621.162791     5738.372093  0.386896

# %%
df.iloc[43,0]
# Out:
# '\u3000\u3000 2\u3000'

# %%
df.to_csv('test.csv')

# %%
#df.iloc[0,0] = 21
df.iloc[17,0] = 38
df.iloc[43,0] = 1

# %%
df.year_jpn
# Out:
# 13     22
# 14     23
# 15     24
# 16     25
# 17     26
#       ...
# 54    15
# 55    16
# 56    17
# 57    18
# 58    19
# Name: year_jpn, Length: 61, dtype: object

# %%
df['year_jpn'] = df['year_jpn'].astype(str).map(lambda x: x.replace('\u3000', ''))

# %%
df['year_jpn'] = df['year_jpn'].astype(str).map(lambda x: x.replace(' ', ''))

# %%
df.year_jpn
# Out:
# 13    22
# 14    23
# 15    24
# 16    25
# 17    26
#       ..
# 54    15
# 55    16
# 56    17
# 57    18
# 58    19
# Name: year_jpn, Length: 61, dtype: object

# %%
df['non_food_exp'] = df['cons_exp'].astype(int) - df['food_exp'].astype(int)

# %%
df_picked.to_csv('../../Data/Downloaded/post_hh_cns_nom_2.csv', index = False)

# %%
df
# Out:
#    year_jpn year_wst hh_size cons_exp food_exp  non_food_exp
# 13       22     1947     4.7     4684     2952          1732
# 14       23     1948    4.81     8780     5302          3478
# 15       24     1949    4.74    11885     7138          4747
# 16       25     1950    4.79    11980     6880          5100
# 17       26     1951     4.8    14389     7822          6567
# ..      ...      ...     ...      ...      ...           ...
# 54       15     2003    3.21   302623    70260        232363
# 55       16     2004    3.19   304203    70116        234087
# 56       17     2005    3.15   300903    68910        231993
# 57       18     2006    3.12   295332    68178        227154
# 58       19     2007     3.1   297139    68522        228617
#
# [61 rows x 6 columns]

# %%
df['cons_exp_pc'] = df['cons_exp'] / df['hh_size']
df['food_exp_pc'] = df['food_exp'] / df['hh_size']
df['non_food_exp_pc'] = df['non_food_exp'] / df['hh_size']

# %%
df['food_shr'] = df['food_exp'] / df['cons_exp']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
fig, ax = plt.subplots()
df.plot(x = 'year_wst', y = 'food_shr', ax = ax)
plt.title('Food consumption share')
plt.show()
