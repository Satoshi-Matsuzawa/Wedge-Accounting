# %%
import pandas as pd

# %%
url = "https://warp.da.ndl.go.jp/info:ndljp/pid/11423429/www.stat.go.jp/data/chouki/zuhyou/22-14.xls"

# %%
df_original = pd.read_excel(url, header = None, index_col = None)

# %%
df_original
# Out:
#                                                     0    1    2    3    4   \
# 0              ２２－１４　財・サービス分類指数（全国）（昭和３０年～平成２２年，昭和４０年度  NaN  NaN  NaN  NaN
# 1                                             ～平成２１年度）  NaN  NaN  NaN  NaN
# 2    22-14 Consumer Price Index by Goods and Servic...  NaN  NaN  NaN  NaN
# 3                                                  NaN  NaN  NaN  NaN  NaN
# 4                                          (平成17年=100)  NaN  NaN  NaN  NaN
# ..                                                 ...  ...  ...  ...  ...
# 116   1) Products, in principle, made by enterprise...  NaN  NaN  NaN  NaN
# 117   2) To eliminate the gaps in upper-level indic...  NaN  NaN  NaN  NaN
# 118      the indices from January 2008 are multipli...  NaN  NaN  NaN  NaN
# 119           〔資料〕 総務省統計局統計調査部消費統計課物価統計室「消費者物価指数（CPI)」  NaN  NaN  NaN  NaN
# 120  Source:  Statistical Survey Department, Statis...  NaN  NaN  NaN  NaN
#
# ...

# %%
stat_name_jpn = df_original.loc[0,0]

# %%
stat_name_eng = df_original.loc[2,0]

# %%
unit_jpn = df_original.loc[4,0]

# %%
unit_eng = df_original.loc[5,0]

# %%
# remove columns and rows with too many nulls
df_dropped = df_original.loc[df_original.notnull().sum(axis=1) > 2, df_original.notnull().sum() > 2]

# %%
df_original.to_csv('test.csv')

# %%
df_dropped.loc[10:,:]
# Out:
#                           0           1        2      3   \
# 10   Calendar or fiscal year         NaN  General  Goods
# 11                    昭和30年　    C.Y.1955       -    22.9
# 12                      31　　        1956       -    22.9
# 13                      32　　        1957       -    23.7
# 14                      33　　        1958       -    23.2
# ..                       ...         ...      ...    ...
# 108                     17　　        2005      100    100
# 109                     18　　        2006    100.2  100.6
# 110                     19　　        2007    100.6    101
# 111                     20　　        2008    101.7  102.9
# 112                     21　　        2009      100   99.9
#
#                               4                                5   \
# 10   Goods, excluding fresh food  Agricultural & aquatic products
# 11                            -                                16
# 12                            -                              15.7
# ...

# %%
# pick year, both in Japanese and western, and the price index for Goods, Agricultural and Aquatic, and industrial products
df_picked = df_dropped.loc[10:66, [0,1,3,5,9]]

# %%
df_picked
# Out:
#                           0           1      3  \
# 10  Calendar or fiscal year         NaN  Goods
# 11                   昭和30年　    C.Y.1955   22.9
# 12                     31　　        1956   22.9
# 13                     32　　        1957   23.7
# 14                     33　　        1958   23.2
# 15                     34　　        1959   23.3
# 16                     35　　        1960   24.1
# 17                     36　　        1961   25.1
# 18                     37　　        1962   26.6
# 19                     38　　        1963   28.5
# 20                     39　　        1964   29.3
# 21                     40　　        1965   31.1
# 22                     41　　        1966   32.2
# 23                     42　　        1967   33.4
# 24                     43　　        1968     35
# 25                     44　　        1969   36.8
# 26                   　45  　        1970   39.6
# 27                     46　　        1971   41.8
# 28                     47　　        1972   43.1
# ...

# %%
df_picked.columns = ['year_jpn', 'year_wst', 'pi_goods', 'pi_ag', 'pi_ind']

# %%
df_picked.loc[11,'year_jpn'] = 30

# %%
df_picked.loc[45,'year_jpn'] = 1

# %%
df_picked.loc[11,'year_wst'] = 1955

# %%
df_picked['year_jpn'] = df_picked['year_jpn'].astype(str).map(lambda x: x.rstrip('\u3000\u3000'))

# %%
df_picked['year_wst'] = df_picked['year_wst'].astype(str)

# %%
df_picked.to_csv('../../Data/Downloaded/post_price.csv', index = False)
