# %%
import pandas as pd

# %%
url = "https://warp.da.ndl.go.jp/info:ndljp/pid/11423429/www.stat.go.jp/data/chouki/zuhyou/02-01.xls"
df_original = pd.read_excel(url, header=None, index_col=None)

# %%
df_original
# Out:
#                                                     0    1    2    3    4   \
# 0                     ２－１　男女別人口・人口増減及び人口密度（明治５年～平成２１年）  NaN  NaN  NaN  NaN
# 1    2-1 Population by Sex, Population Increase and...  NaN  NaN  NaN  NaN
# 2                                                  NaN  NaN  NaN  NaN  NaN
# 3                                         (単位  1,000人)  NaN  NaN  NaN  NaN
# 4                            (In thousands of persons)  NaN  NaN  NaN  NaN
# ..                                                 ...  ...  ...  ...  ...
# 261                      〔資料〕 総務省統計局統計調査部国勢統計課「国勢調査報告」  NaN  NaN  NaN  NaN
# 262                           総務省統計局統計調査部国勢統計課「人口推計資料」  NaN  NaN  NaN  NaN
# 263                                 内閣統計局「明治五年以降我国の人口」  NaN  NaN  NaN  NaN
# 264  Source:   Statistical Survey Department, Stati...  NaN  NaN  NaN  NaN
# 265                                    Communications.  NaN  NaN  NaN  NaN
#
#       5       6    7    8    9    10   11  12   13
# ...

# %%
stat_name_jpn = df_original.iloc[0,0]

# %%
stat_name_eng = df_original.iloc[1,0]

# %%
unit_jpn = df_original.iloc[3,0]

# %%
unit_eng = df_original.iloc[4,0]

# %%
# Remove columns and rows with too many nulls
df_dropped = df_original.loc[df_original.notnull().sum(axis=1) > 2, df_original.notnull().sum() > 2]

# %%
df_dropped
# Out:
#         0     1       2      3       4             5   \
# 5       年次   NaN      人口    NaN     NaN         人口増減数
# 7      NaN   NaN      総数      男       女             計
# 9     Year   NaN   Total   Male  Female  Total  \n 3)
# 10   明治 5年  1872   34806  17666   17140           179
# 11      6　  1873   34985  17755   17230           169
# ..     ...   ...     ...    ...     ...           ...
# 145    17　  2005  127768  62349   65419           -19
# 146    18　  2006  127770  62330   65440             2
# 147    19　  2007  127771  62310   65461             1
# 148    20　  2008  127692  62251   65441           -79
# 149    21　  2009  127510  62130   65380          -183
#
#                                        6            7                  8   \
# 5                                     NaN          NaN                NaN
# 7                                    自然増減          NaN                NaN
# 9    Natural \nincrease and decrease\n 4)  Live births  Number of  Deaths
# ...

# %%
df_picked = df_dropped.loc[10:,[1,2]]

# %%
df_picked.columns = ['year_wst', 'tot_pop']

# %%
# convert units from 1000 people to people 
convert_units = 1000
df_picked['tot_pop'] = df_picked['tot_pop'] * convert_units

# %%
df_picked.loc[109]
# Out:
# year_wst         1970
# tot_pop     103720000
# Name: 109, dtype: object

# %%
df_picked_2 = df_picked.drop([110])

# %%
df_picked_2.loc[109]
# Out:
# year_wst         1970
# tot_pop     103720000
# Name: 109, dtype: object

# %%
df_picked_2.year_wst = df_picked_2.year_wst.astype(int)

# %%
df_picked_2.to_csv('../../Data/Downloaded/post_pop.csv', index = False)
