# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df_emp_pre = pd.read_csv('../../Data/Downloaded/pre_emp.csv')
df_emp_post = pd.read_csv('../../Data/Downloaded/post_emp.csv')

# %%
df_emp_pre['tot_emp'] = df_emp_pre['prm_emp'] + df_emp_pre['non_prm_emp']
df_emp_post['tot_emp'] = df_emp_post['prm_emp'] + df_emp_post['non_prm_emp']

# %%
df_emp_pre['prm_emp_shr'] = df_emp_pre['prm_emp'] / df_emp_pre['tot_emp']
df_emp_pre['non_prm_emp_shr'] = df_emp_pre['non_prm_emp'] / df_emp_pre['tot_emp']

# %%
df_emp_post['prm_emp_shr'] = df_emp_post['prm_emp'] / df_emp_post['tot_emp']
df_emp_post['non_prm_emp_shr'] = df_emp_post['non_prm_emp'] / df_emp_post['tot_emp']

# %%
df_emp_pre_picked = df_emp_pre[['year_wst', 'prm_emp', 'non_prm_emp', 'prm_emp_shr', 'non_prm_emp_shr']]

# %%
df_emp_post_picked = df_emp_post[['year_wst', 'prm_emp', 'non_prm_emp', 'prm_emp_shr', 'non_prm_emp_shr']]

# %%
# adjust unit to persons 
adj_unit_post = 10000

# %%
df_emp_post_picked['prm_emp'] = df_emp_post_picked['prm_emp'] * adj_unit_post
df_emp_post_picked['non_prm_emp'] = df_emp_post_picked['non_prm_emp'] * adj_unit_post
# Out:
# <ipython-input-9-93bb284bfcf0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emp_post_picked['prm_emp'] = df_emp_post_picked['prm_emp'] * adj_unit_post
# <ipython-input-9-93bb284bfcf0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emp_post_picked['non_prm_emp'] = df_emp_post_picked['non_prm_emp'] * adj_unit_post

# %%
df_merged = pd.concat([df_emp_pre_picked, df_emp_post_picked])

# %%
# convert unit to million people
adj_unit_mil = 1e6

# %%
df_merged['prm_emp_mil'] = df_merged['prm_emp'] / adj_unit_mil
df_merged['non_prm_emp_mil'] = df_merged['non_prm_emp'] / adj_unit_mil

# %%
df_merged
# Out:
#     year_wst   prm_emp  non_prm_emp  prm_emp_shr  non_prm_emp_shr  \
# 0       1906  15394100      9287400     0.623710         0.376290
# 1       1907  15447500      9475600     0.619807         0.380193
# 2       1908  15381000      9621100     0.615188         0.384812
# 3       1909  15287700      9768600     0.610134         0.389866
# 4       1910  15307700      9825800     0.609056         0.390944
# ..       ...       ...          ...          ...              ...
# 45      1998   3430000     59180000     0.054784         0.945216
# 46      1999   3350000     58720000     0.053971         0.946029
# 47      2000   3260000     58680000     0.052632         0.947368
# 48      2001   3130000     58430000     0.050845         0.949155
# 49      2002   2960000     57620000     0.048861         0.951139
#
#     prm_emp_mil  non_prm_emp_mil
# 0       15.3941           9.2874
# 1       15.4475           9.4756
# 2       15.3810           9.6211
# 3       15.2877           9.7686
# 4       15.3077           9.8258
# ..          ...              ...
# 45       3.4300          59.1800
# 46       3.3500          58.7200
# 47       3.2600          58.6800
# 48       3.1300          58.4300
# 49       2.9600          57.6200
#
# [85 rows x 7 columns]

# %%
df_merged['tot_emp_mil'] = df_merged['prm_emp_mil'] + df_merged['non_prm_emp_mil']

# %%
df_merged['prm_emp_shr'] = df_merged['prm_emp_mil'] / df_merged['tot_emp_mil']
df_merged['non_prm_emp_shr'] = df_merged['non_prm_emp_mil'] / df_merged['tot_emp_mil']

# %%
df_merged
# Out:
#     year_wst   prm_emp  non_prm_emp  prm_emp_shr  non_prm_emp_shr  \
# 0       1906  15394100      9287400     0.623710         0.376290
# 1       1907  15447500      9475600     0.619807         0.380193
# 2       1908  15381000      9621100     0.615188         0.384812
# 3       1909  15287700      9768600     0.610134         0.389866
# 4       1910  15307700      9825800     0.609056         0.390944
# ..       ...       ...          ...          ...              ...
# 45      1998   3430000     59180000     0.054784         0.945216
# 46      1999   3350000     58720000     0.053971         0.946029
# 47      2000   3260000     58680000     0.052632         0.947368
# 48      2001   3130000     58430000     0.050845         0.949155
# 49      2002   2960000     57620000     0.048861         0.951139
#
#     prm_emp_mil  non_prm_emp_mil  tot_emp_mil
# 0       15.3941           9.2874      24.6815
# 1       15.4475           9.4756      24.9231
# 2       15.3810           9.6211      25.0021
# 3       15.2877           9.7686      25.0563
# 4       15.3077           9.8258      25.1335
# ..          ...              ...          ...
# 45       3.4300          59.1800      62.6100
# 46       3.3500          58.7200      62.0700
# 47       3.2600          58.6800      61.9400
# 48       3.1300          58.4300      61.5600
# 49       2.9600          57.6200      60.5800
#
# [85 rows x 8 columns]

# %%
fig, ax = plt.subplots()
df_merged.plot(x = 'year_wst', y = 'prm_emp_mil', ax = ax)
plt.title('Primary industry employment (million people)')
plt.show()

# %%
fig, ax = plt.subplots()
df_merged.plot(x = 'year_wst', y = 'prm_emp_shr', ax = ax)
plt.title('Primary industry employment share')
plt.show()

# %%
fig, ax = plt.subplots()
df_merged.plot(x = 'year_wst', y = 'non_prm_emp_mil', ax = ax)
plt.title('Non primary industry employment (million people)')
plt.show()

# %%
fig, ax = plt.subplots()
df_merged.plot(x = 'year_wst', y = 'non_prm_emp_shr', ax = ax)
plt.title('Non primary industry employment share')
plt.show()

# %%
df_pre = df_emp_pre_picked
df_post = df_emp_post_picked

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
#df_pre.plot(x = 'year_wst', y = 'prm_cap_p90_bil', 
df_pre[df_pre.year_wst >= 1920].plot(x = 'year_wst', y = 'prm_emp', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#df_post.plot(x = 'year_wst', y = 'tot_cns_p90_mth',  
df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'prm_emp',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Primary industry employment (people)')
plt.savefig('../../Notes/Facts/comb_prm_emp.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
#df_pre.plot(x = 'year_wst', y = 'prm_cap_p90_bil', 
df_pre[df_pre.year_wst >= 1920].plot(x = 'year_wst', y = 'prm_emp_shr', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               #marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)
#df_post.plot(x = 'year_wst', y = 'tot_cns_p90_mth',  
df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'prm_emp_shr',
               #marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Primary industry employment share')
plt.savefig('../../Notes/Facts/comb_prm_emp_shr.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
#df_pre.plot(x = 'year_wst', y = 'prm_cap_p90_bil', 
df_pre[df_pre.year_wst >= 1920].plot(x = 'year_wst', y = 'non_prm_emp_shr', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               #marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)
#df_post.plot(x = 'year_wst', y = 'tot_cns_p90_mth',  
df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'non_prm_emp_shr',  
               #marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Non-primary industry employment share')
plt.savefig('../../Notes/Facts/comb_non_prm_emp_shr.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
#df_pre.plot(x = 'year_wst', y = 'prm_cap_p90_bil', 
df_pre[df_pre.year_wst >= 1920].plot(x = 'year_wst', y = 'non_prm_emp', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#df_post.plot(x = 'year_wst', y = 'tot_cns_p90_mth',  
df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'non_prm_emp',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Non-primary industry employment (people)')
plt.savefig('../../Notes/Facts/comb_non_prm_emp.pdf')
plt.show()

# %%
df_post
# Out:
#     year_wst   prm_emp  non_prm_emp  prm_emp_shr  non_prm_emp_shr
# 0       1953  15590000     22220000     0.412325         0.587675
# 1       1954  15070000     23120000     0.394606         0.605394
# 2       1955  15360000     24230000     0.387977         0.612023
# 3       1956  15000000     25390000     0.371379         0.628621
# 4       1957  14670000     26860000     0.353239         0.646761
# 5       1958  14080000     27560000     0.338136         0.661864
# 6       1959  13480000     28410000     0.321795         0.678205
# 7       1960  13400000     29540000     0.312063         0.687937
# 8       1961  13030000     30440000     0.299747         0.700253
# 9       1962  12670000     31370000     0.287693         0.712307
# 10      1963  11940000     32400000     0.269283         0.730717
# 11      1964  11490000     33440000     0.255731         0.744269
# 12      1965  11130000     34580000     0.243492         0.756508
# 13      1966  10720000     36000000     0.229452         0.770548
# 14      1967  10360000     37270000     0.217510         0.782490
# 15      1968   9880000     38550000     0.204006         0.795994
# 16      1969   9460000     39330000     0.193892         0.806108
# 17      1970   8860000     40390000     0.179898         0.820102
# 18      1971   8150000     41330000     0.164713         0.835287
# 19      1972   7550000     41880000     0.152741         0.847259
# 20      1973   7050000     43630000     0.139108         0.860892
# 21      1974   6750000     43590000     0.134088         0.865912
# 22      1975   6610000     43550000     0.131778         0.868222
# 23      1976   6430000     44280000     0.126799         0.873201
# 24      1977   6340000     45040000     0.123394         0.876606
# 25      1978   6330000     45680000     0.121707         0.878293
# 26      1979   6130000     46560000     0.116341         0.883659
# 27      1980   5770000     47470000     0.108377         0.891623
# 28      1981   5570000     48190000     0.103609         0.896391
# 29      1982   5480000     48790000     0.100977         0.899023
# 30      1983   5310000     49920000     0.096143         0.903857
# 31      1984   5120000     50390000     0.092236         0.907764
# 32      1985   5090000     50760000     0.091137         0.908863
# 33      1986   4950000     51390000     0.087859         0.912141
# 34      1987   4890000     52000000     0.085955         0.914045
# 35      1988   4740000     53130000     0.081908         0.918092
# 36      1989   4630000     54460000     0.078355         0.921645
# 37      1990   4510000     55730000     0.074867         0.925133
# 38      1991   4270000     57130000     0.069544         0.930456
# 39      1992   4110000     57910000     0.066269         0.933731
# 40      1993   3830000     58300000     0.061645         0.938355
# 41      1994   3730000     58360000     0.060074         0.939926
# 42      1995   3670000     58470000     0.059060         0.940940
# 43      1996   3560000     58860000     0.057033         0.942967
# 44      1997   3500000     59580000     0.055485         0.944515
# 45      1998   3430000     59180000     0.054784         0.945216
# 46      1999   3350000     58720000     0.053971         0.946029
# 47      2000   3260000     58680000     0.052632         0.947368
# 0      3781     0.412325         0.587675
# 1      3819     0.394606         0.605394
# 2      3959     0.387977         0.612023
# 3      4039     0.371379         0.628621
# 4      4153     0.353239         0.646761
# 5      4164     0.338136         0.661864
# 6      4189     0.321795         0.678205
# 7      4294     0.312063         0.687937
# 8      4347     0.299747         0.700253
# 9      4404     0.287693         0.712307
# 10     4434     0.269283         0.730717
# 11     4493     0.255731         0.744269
# 12     4571     0.243492         0.756508
# 13     4672     0.229452         0.770548
# 14     4763     0.217510         0.782490
# 15     4843     0.204006         0.795994
# 16     4879     0.193892         0.806108
# 17     4925     0.179898         0.820102
# 18     4948     0.164713         0.835287
# 19     4943     0.152741         0.847259
# 20     5068     0.139108         0.860892
# 21     5034     0.134088         0.865912
# 22     5016     0.131778         0.868222
# 23     5071     0.126799         0.873201
# 24     5138     0.123394         0.876606
# 25     5201     0.121707         0.878293
# 26     5269     0.116341         0.883659
# 27     5324     0.108377         0.891623
# 28     5376     0.103609         0.896391
# 29     5427     0.100977         0.899023
# 30     5523     0.096143         0.903857
# 31     5551     0.092236         0.907764
# 32     5585     0.091137         0.908863
# 33     5634     0.087859         0.912141
# 34     5689     0.085955         0.914045
# 35     5787     0.081908         0.918092
# 36     5909     0.078355         0.921645
# 37     6024     0.074867         0.925133
# 38     6140     0.069544         0.930456
# 39     6202     0.066269         0.933731
# 40     6213     0.061645         0.938355
# 41     6209     0.060074         0.939926
# 42     6214     0.059060         0.940940
# 43     6242     0.057033         0.942967
# 44     6308     0.055485         0.944515
# 45     6261     0.054784         0.945216
# 46     6207     0.053971         0.946029
# 47     6194     0.052632         0.947368
# 48     6156     0.050845         0.949155
# 49     6058     0.048861         0.951139

# %%
df_merged.to_csv()
# Out:
#     year_wst   prm_emp  non_prm_emp  prm_emp_shr  non_prm_emp_shr  \
# 0       1906  15394100      9287400     0.623710         0.376290
# 1       1907  15447500      9475600     0.619807         0.380193
# 2       1908  15381000      9621100     0.615188         0.384812
# 3       1909  15287700      9768600     0.610134         0.389866
# 4       1910  15307700      9825800     0.609056         0.390944
# ..       ...       ...          ...          ...              ...
# 45      1998   3430000     59180000     0.054784         0.945216
# 46      1999   3350000     58720000     0.053971         0.946029
# 47      2000   3260000     58680000     0.052632         0.947368
# 48      2001   3130000     58430000     0.050845         0.949155
# 49      2002   2960000     57620000     0.048861         0.951139
#
#     prm_emp_mil  non_prm_emp_mil  tot_emp_mil
# 0       15.3941           9.2874      24.6815
# 1       15.4475           9.4756      24.9231
# 2       15.3810           9.6211      25.0021
# 3       15.2877           9.7686      25.0563
# 4       15.3077           9.8258      25.1335
# ..          ...              ...          ...
# 45       3.4300          59.1800      62.6100
# 46       3.3500          58.7200      62.0700
# 47       3.2600          58.6800      61.9400
# 48       3.1300          58.4300      61.5600
# 49       2.9600          57.6200      60.5800
#
# [85 rows x 8 columns]
