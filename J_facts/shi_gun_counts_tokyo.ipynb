# %%
# This memo shows the number of cities and rural districts.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df_shi = pd.read_csv('../../Data/Downloaded/num_of_mun_shi.csv')

# %%
df_cho = pd.read_csv('../../Data/Downloaded/num_of_mun_cho.csv')

# %%
df_son = pd.read_csv('../../Data/Downloaded/num_of_mun_son.csv')

# %%
df_cho
# Out:
#    year_jpn  year_wst  total  Hokkaido  Aomori  Iwate  Miyagi  Akita  \
# 0     大正 9年    1920.0   1365        31      15     23      36     43
# 1       14　    1925.0   1532        42      20     25      38     45
# 2     昭和 5年    1930.0   1704        43      23     27      39     47
# 3       10　    1935.0   1708        46      24     28      38     52
# 4       15　    1940.0   1762        51      25     28      39     53
# 5       20　    1945.0   1803        57      30     33      44     49
# 6       25　    1950.0   1889        75      31     32      47     51
# 7       30　    1955.0   1873       112      30     25      53     42
# 8       35　    1960.0   1933       127      30     27      57     39
# 9       40　    1965.0   2008       151      32     29      62     43
# 10      45　    1970.0   2020       157      33     32      63     45
# 11      50　    1975.0   1976       154      33     31      60     48
# 12      55　    1980.0   1993       155      34     31      61     48
# ...

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_shi.plot(x = 'year_wst', y = 'total', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Number of cities (total)')
plt.savefig('../../Notes/Facts/num_of_mun_tot.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_cho.plot(x = 'year_wst', y = 'total', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Number of cities (total)')
plt.savefig('../../Notes/Facts/num_of_mun_tot.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_son.plot(x = 'year_wst', y = 'total', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Number of cities (total)')
plt.savefig('../../Notes/Facts/num_of_mun_tot.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_shi.plot(x = 'year_wst', y = 'Tokyo', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Number of cities (tokyo)')
plt.savefig('../../Notes/Facts/num_of_mun_tokyo.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_cho.plot(x = 'year_wst', y = 'Tokyo', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Number of Cho (tokyo)')
plt.savefig('../../Notes/Facts/num_of_mun_tokyo.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_son.plot(x = 'year_wst', y = 'Tokyo', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               #linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
#ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title('Number of Cho (tokyo)')
plt.savefig('../../Notes/Facts/num_of_mun_tokyo.pgf')
plt.show()
