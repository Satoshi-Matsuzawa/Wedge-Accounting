# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# import matplotlib as mpl
# # Use the pgf backend (must be set before pyplot imported)
# mpl.use('pgf')

# %%
df_pre = pd.read_csv('../../Data/Results/pre_labor_w.csv')
df_post = pd.read_csv('../../Data/Results/post_labor_w.csv')

# %%
df_merged = pd.concat([df_pre, df_post])

# %%
df_merged.columns
# Out:
# Index(['year_wst', 'food', 'cons', 'non_food', 'food-PA_gammaA',
#        'PA_cA-gammaA/PM_cM', 'muM/PM/muA/PA', 'prm_emp', 'scn_emp', 'trt_emp',
#        'mil', 'non_prm_emp', 'prm_GDP', 'tot_GDP', 'non_prm_GDP', 'F_LA',
#        'F_LM', 'F_LM/F_LA', 'LM/LA', 'YM/YA', 'labor_wedge', 'year_jpn_x',
#        'pub_emp', 'year_jpn_y', 'tot_prv_GDP'],
#       dtype='object')

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'labor_wedge', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'labor_wedge',  
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor wedge $\tau_{W}$}')
plt.savefig('../../Notes/Discussion/labor_w.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'YM/YA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'LM/LA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'c',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'YM/YA',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'LM/LA',  
               marker = '.',
               linestyle = '--',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L_M/L_A$ and output ratio $Y_M/Y_A$}')
#plt.savefig('../../Notes/Discussion/output_labor_ratio.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_LM/F_LA', 
#               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'F_LM/F_LA',  
               linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor productivity ratio $P^{M}F^{M}_{L}/P^{A}F^{A}_{L}$}')
plt.savefig('../../Notes/Discussion/labor_prod_ratio.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_LM/F_LA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'muM/PM/muA/PA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '-.',
               color = 'c',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'F_LM/F_LA',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'muM/PM/muA/PA',  
               marker = '.',
               linestyle = '-.',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Normalized labor wedge $\tau_{W,t}$}')
#plt.savefig('../../Notes/comb_lab_w.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'YM/YA', 
               label = r'$P^{M}Y^{M}/P^{A}Y^{A}$', 
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'LM/LA', 
               label = r'$L_M/L_A$', 
               linestyle = '-.',
               color = 'c',
               ax = ax)

df_post[df_post.year_wst <= 1980].plot(x = 'year_wst', y = 'YM/YA',  
               label = '_nolegend_',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 1980].plot(x = 'year_wst', y = 'LM/LA',  
               label = '_nolegend_',
               linestyle = '-.',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
# ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L_M/L_A$ and output ratio $P^{M}Y^{M}/P^{A}Y^{A}$}')
plt.savefig('../../Notes/Discussion/output_labor_ratio.pgf')
plt.show()
# Out:
# /Users/satoshi/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:633: UserWarning: The handle <matplotlib.lines.Line2D object at 0x160e92370> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# /Users/satoshi/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:633: UserWarning: The handle <matplotlib.lines.Line2D object at 0x161338df0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'YM/YA', 
               label = r'$Y_M/Y_A$', 
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'LM/LA', 
               label = r'$L_M/L_A$', 
               linestyle = '-.',
               color = 'c',
               ax = ax)

#df_post[df_post.year_wst <= 1980].plot(x = 'year_wst', y = 'YM/YA',  
#               label = '_nolegend_',
#               linestyle = '--',
#              color = 'b',
#               ax = ax)

#df_post[df_post.year_wst <= 1980].plot(x = 'year_wst', y = 'LM/LA',  
#               label = '_nolegend_',
#               linestyle = '-.',
#               color = 'c',
#               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L_M/L_A$ and output ratio $P^{M}Y^{M}/P^{A}Y^{A}$}')
#plt.savefig('../../Notes/Discussion/output_labor_ratio.pgf')
plt.show()

# %%
df_pre[['year_wst', 'LM/LA', 'YM/YA']]
# Out:
#     year_wst     LM/LA     YM/YA
# 0       1906  0.603309  2.142793
# 1       1907  0.613407  2.053782
# 2       1908  0.625518  2.041147
# 3       1909  0.638984  2.030290
# 4       1910  0.641886  2.237576
# 5       1911  0.642278  2.205401
# 6       1912  0.646964  2.331693
# 7       1913  0.655707  2.329160
# 8       1914  0.657198  1.945448
# 9       1915  0.721167  2.253066
# 10      1916  0.737627  2.439198
# 11      1917  0.743718  2.656784
# 12      1918  0.814304  2.815495
# 13      1919  0.811505  2.889111
# 14      1920  0.830781  2.664879
# 15      1921  0.846053  3.522094
# 16      1922  0.867518  3.394489
# 17      1923  0.969045  3.519761
# 2             0.522346       2.959963  15381000  4193300  5582500  ...
# 3             0.461611       2.615798  15287700  4299200  5610600  ...
# 4             0.533713       3.024375  15307700  4262000  5697100  ...
# ..                 ...            ...       ...      ...      ...  ...
# 39            0.187212       1.060868       373     2157     3894  ...
# 40            0.184349       1.044643       367     2125     3940  ...
# 41            0.183846       1.041792       356     2121     3979  ...
# 42            0.183840       1.041758       350     2134     4039  ...
# 43            0.184319       1.044475       343     2050     4085  ...
#
#          F_LA       F_LM  F_LM/F_LA      LM/LA      YM/YA  labor_wedge  \
# 0    0.000080   0.000176   2.195617   0.603309   2.142793     4.073219
# 1    0.000085   0.000175   2.069769   0.613407   2.053782     4.093582
# 2    0.000086   0.000174   2.017207   0.625518   2.041147     5.970856
# 3    0.000087   0.000170   1.964193   0.638984   2.030290     5.137932
# 4    0.000082   0.000178   2.154945   0.641886   2.237576     6.517360
# ..        ...        ...        ...        ...        ...          ...
# 39  14.984035  24.661663   1.645863  15.646113  41.656600     1.746044
# 40  14.466199  25.149376   1.738492  15.931880  44.804701     1.816103
# 41  15.332177  26.109713   1.702936  16.533708  45.546216     1.774104
# 42  14.964714  26.239018   1.753392  17.022857  48.283125     1.826611
# 43  14.859140  25.642911   1.725733  17.253644  48.165744     1.802485
#
#     year_jpn_x  pub_emp  year_jpn_y  tot_prv_GDP
# 0          NaN      NaN         NaN          NaN
# 1          NaN      NaN         NaN          NaN
# 2          NaN      NaN         NaN          NaN
# 3          NaN      NaN         NaN          NaN
# 4          NaN      NaN         NaN          NaN
# ..         ...      ...         ...          ...
# 39         6.0    215.0         6.0     433472.1
# 40         7.0    218.0         7.0     442148.2
# 41         8.0    214.0         8.0     461929.3
# 42         9.0    215.0         9.0     469323.2
# 43        10.0    217.0        10.0     455604.2
#
# [79 rows x 25 columns]

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_LM/F_LA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'F_LM/F_LA',  
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor productivity}')
plt.savefig('../../Notes/comb_lab_w.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'muM/PM/muA/PA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'muM/PM/muA/PA',  
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Ratio of expenditures $P_AC_A/P_MC_M$}')
plt.savefig('../../Notes/comb_lab_w.pdf')
plt.show()

# %%
df_pre['prm_emp_share'] = df_pre.prm_emp / df_pre.tot_emp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hb/3db8mbcj4l74ztsvqyx17yd00000gn/T/ipykernel_36255/577716767.py in <module>
# ----> 1 df_pre['prm_emp_share'] = df_pre.prm_emp / df_pre.tot_emp
#
# ~/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tot_emp'
