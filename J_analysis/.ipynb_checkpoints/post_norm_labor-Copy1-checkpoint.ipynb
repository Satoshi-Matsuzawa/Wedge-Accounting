# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read csv files
df_emp = pd.read_csv('../../Data/Downloaded_Old/post_emp.csv')
df_GDP = pd.read_csv('../../Data/Downloaded_Old/post_GDP.csv')
df_cns = pd.read_csv('../../Data/Downloaded_Old/post_real_cns.csv')

# %%
# parameters
α_KA  = 0.15
α_LA  = 0.55
α_KM  = 0.6
α_LM  = 0.4
η     = 0.15
γ_pre = 60
#γ_post = 76.4
γ_post = 68.8 
δ     = 0.05
β     = 0.96

# %%
# create the ratio of marginal utility
df_cns['cA-γ/cM'] = (df_cns['real_food_cns'] - γ_post) / df_cns['real_non_food_cns']
df_cns['mu_M/mu_A'] = (1-η) / η * df_cns['cA-γ/cM']

# %%
df_cns
# Out:
#    year_jpn  year_wst  real_tot_cns  real_food_cns  real_non_food_cns  \
# 0        30      1955    219.394991     139.756944          79.638047
# 1        31      1956    233.581075     146.215604          87.365471
# 2        32      1957    251.353486     153.192145          98.161341
# 3        33      1958    280.616571     166.465446         114.151125
# 4        34      1959    298.044826     169.487592         128.557234
# 5        35      1960    322.435775     178.231156         144.204619
# 6        36      1961    350.196193     184.298908         165.897284
# 7        37      1962    374.407538     186.695944         187.711594
# 8        38      1963    378.551365     180.203502         198.347863
# 9        39      1964    405.555209     190.008703         215.546506
# 10       40      1965    423.022508     186.750327         236.272181
# 11       41      1966    452.327505     190.419428         261.908077
# 12       42      1967    498.405455     201.727451         296.678004
# 13       43      1968    534.506122     203.784787         330.721336
# 14       44      1969    563.687888     207.828746         355.859142
# 15    　45        1970    604.464939     211.864947         392.599993
# 16       46      1971    646.109963     228.319654         417.790309
# 17       47      1972    694.280603     243.327641         450.952961
# 18       48      1973    724.386242     243.665324         480.720918
# 19       49      1974    695.498430     244.588455         450.909975
# 20       50      1975    734.248756     240.680095         493.568662
# 21       51      1976    756.830464     237.937114         518.893350
# 22       52      1977    780.327132     235.190994         545.136138
# 23       53      1978    795.321995     238.678624         556.643370
# 24       54      1979    829.095382     240.502209         588.593173
# 25       55      1980    820.332093     241.010100         579.321994
# 26       56      1981    835.711340     240.747716         594.963624
# 27       57      1982    865.386242     248.130621         617.255621
# 28       58      1983    872.432692     246.766493         625.666200
# 29       59      1984    907.120832     249.661950         657.458882
# 30       60      1985    908.115315     244.660622         663.454692
# 31       61      1986    926.721961     249.543492         677.178470
# 32       62      1987    956.322916     254.074197         702.248719
# 33       63      1988   1015.080624     259.837625         755.242998
# 34        1      1989   1034.379188     263.534660         770.844527
# 35        2      1990   1066.925144     260.448988         806.476155
# 36        3      1991   1076.159415     254.134027         822.025388
# 37      4        1992   1106.941839     269.382498         837.559341
# 38        5      1993   1121.735287     266.895128         854.840159
# 39        6      1994   1119.741244     260.674768         859.066476
# 40        7      1995   1140.029474     264.937044         875.092430
# 41        8      1996   1178.823372     267.196744         911.626627
# 42        9      1997   1207.014560     275.557901         931.456658
# 43      　10      1998   1182.511439     265.394356         917.117083
# 44       11      1999   1174.978956     267.477402         907.501555
# 45       12      2000   1183.356239     272.700459         910.655780
# 46       13      2001   1183.998586     267.715383         916.283203
# 47       14      2002   1194.807400     271.947831         922.859570
# 48       15      2003   1178.161792     260.483965         917.677828
# 49       16      2004   1212.670811     256.587010         956.083801
# 50       17      2005   1226.302239     264.791045         961.511194
# 51       18      2006   1200.442627     256.596374         943.846253
# 52       19      2007   1220.207273     260.193153         960.014121
#
#      cA-γ/cM  mu_M/mu_A
# 0   0.890993   5.048960
# 1   0.886112   5.021302
# 2   0.859729   4.871797
# 3   0.855580   4.848288
# 4   0.783212   4.438202
# 5   0.758860   4.300208
# 6   0.696207   3.945175
# 7   0.628070   3.559061
# 8   0.561657   3.182724
# 9   0.562332   3.186548
# 10  0.499214   2.828878
# 11  0.464359   2.631369
# 12  0.448053   2.538967
# 13  0.408153   2.312865
# 14  0.390685   2.213880
# 15  0.364404   2.064955
# 16  0.381818   2.163633
# 17  0.387020   2.193111
# 18  0.363756   2.061286
# 19  0.389853   2.209165
# 20  0.348239   1.973357
# 21  0.325957   1.847092
# 22  0.305228   1.729627
# 23  0.305184   1.729376
# 24  0.291716   1.653059
# 25  0.297261   1.684482
# 26  0.289005   1.637697
# 27  0.290529   1.646331
# 28  0.284443   1.611845
# 29  0.275092   1.558857
# 30  0.265068   1.502052
# 31  0.266907   1.512471
# 32  0.263830   1.495036
# 33  0.252949   1.433375
# 34  0.252625   1.431542
# 35  0.237638   1.346613
# 36  0.225460   1.277608
# 37  0.239485   1.357079
# 38  0.231734   1.313157
# 39  0.223353   1.265665
# 40  0.224133   1.270087
# 41  0.217629   1.233233
# 42  0.221973   1.257845
# 43  0.214361   1.214714
# 44  0.218928   1.240591
# 45  0.223905   1.268795
# 46  0.217089   1.230173
# 47  0.220129   1.247396
# 48  0.208879   1.183650
# 49  0.196413   1.113005
# 50  0.203836   1.155073
# 51  0.198969   1.127492
# 52  0.199365   1.129735

# %%
df_GDP_emp = pd.merge(df_GDP, df_emp, on = 'year_wst')

# %%
df_GDP_emp_picked = df_GDP_emp[['year_wst', 'prm_GDP', 'non_prm_GDP', 'prm_emp', 'non_prm_emp']]

# %%
df_GDP_emp_picked['F_LA'] = α_LA * df_GDP_emp_picked['prm_GDP'] / df_GDP_emp_picked['prm_emp']
# Out:
# /Users/satoshi/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_GDP_emp_picked['F_LM'] = α_LM * df_GDP_emp_picked['non_prm_GDP'] / df_GDP_emp_picked['non_prm_emp']

# %%
# get the ratio of labor productivity
df_GDP_emp_picked['F_LM/F_LA'] = df_GDP_emp_picked['F_LM'] / df_GDP_emp_picked['F_LA']

# %%
df_merged = pd.merge(df_GDP_emp_picked[['year_wst', 'F_LM/F_LA']], 
                    df_cns[['year_wst', 'mu_M/mu_A']], on = 'year_wst')

# %%
df_merged['norm_labor_wedge'] = df_merged['mu_M/mu_A'] * df_merged['F_LM/F_LA']

# %%
df_merged['norm_labor_wedge-1'] = df_merged['norm_labor_wedge'] - 1

# %%
fig, ax = plt.subplots()
df_merged.plot(x = 'year_wst', y = 'norm_labor_wedge-1', ax = ax)
plt.legend()

# %%
df_merged.to_csv('../../Data/Results/post_lab_w.csv', index = False)

# %%
df_merged.loc[0:4]['norm_labor_wedge-1'].mean()
# Out:
# 7.3116572948222025

# %%
df_merged
# Out:
#     year_wst  F_LM/F_LA  mu_M/mu_A  norm_labor_wedge  norm_labor_wedge-1
# 0       1955   1.695264   5.048960          8.559319            7.559319
# 1       1956   1.784167   5.021302          8.958842            7.958842
# 2       1957   1.762747   4.871797          8.587747            7.587747
# 3       1958   1.716479   4.848288          8.321983            7.321983
# 4       1959   1.606595   4.438202          7.130395            6.130395
# 5       1960   1.714584   4.300208          7.373070            6.373070
# 6       1961   1.764180   3.945175          6.959997            5.959997
# 7       1962   1.801952   3.559061          6.413256            5.413256
# 8       1963   1.868350   3.182724          5.946443            4.946443
# 9       1964   1.907048   3.186548          6.076899            5.076899
# 10      1965   1.902133   2.828878          5.380904            4.380904
# 11      1966   1.900243   2.631369          5.000239            4.000239
# 12      1967   1.993678   2.538967          5.061882            4.061882
# 13      1968   2.172912   2.312865          5.025652            4.025652
# 14      1969   2.353433   2.213880          5.210219            4.210219
# 15      1970   2.673924   2.064955          5.521533            4.521533
# 16      1971   2.696150   2.163633          5.833479            4.833479
# 17      1972   2.371111   2.193111          5.200109            4.200109
# 18      1973   2.161492   2.061286          4.455455            3.455455
# 19      1974   2.082211   2.209165          4.599948            3.599948
# 20      1975   2.095290   1.973357          4.134755            3.134755
# 21      1976   2.213647   1.847092          4.088810            3.088810
# 22      1977   2.279810   1.729627          3.943222            2.943222
# 23      1978   2.341172   1.729376          4.048765            3.048765
# 24      1979   2.354677   1.653059          3.892420            2.892420
# 25      1980   2.386249   1.684482          4.019593            3.019593
# 26      1981   2.329258   1.637697          3.814619            2.814619
# 27      1982   2.218960   1.646331          3.653142            2.653142
# 28      1983   2.125534   1.611845          3.426031            2.426031
# 29      1984   2.048913   1.558857          3.193962            2.193962
# 30      1985   2.144450   1.502052          3.221076            2.221076
# 31      1986   2.117713   1.512471          3.202981            2.202981
# 32      1987   2.104181   1.495036          3.145826            2.145826
# 33      1988   2.194843   1.433375          3.146034            2.146034
# 34      1989   2.147615   1.431542          3.074401            2.074401
# 35      1990   2.154717   1.346613          2.901569            1.901569
# 36      1991   2.259995   1.277608          2.887387            1.887387
# 37      1992   2.041341   1.357079          2.770261            1.770261
# 38      1993   2.139342   1.313157          2.809292            1.809292
# 39      1994   1.936309   1.265665          2.450719            1.450719
# 40      1995   2.045285   1.270087          2.597689            1.597689
# 41      1996   2.003454   1.233233          2.470726            1.470726
# 42      1997   2.062815   1.257845          2.594701            1.594701
# 43      1998   2.030274   1.214714          2.466202            1.466202
