# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# import matplotlib as mpl
# # Use the pgf backend (must be set before pyplot imported)
# mpl.use('pgf')

# %%
df_pre = pd.read_csv('../../Data/Results/pre_lab_w.csv')
df_post = pd.read_csv('../../Data/Results/post_lab_w.csv')

# %%
df_merged = pd.concat([df_pre, df_post])

# %%
df_merged
# Out:
#     year_wst  F_LM/F_LA  mu_M/mu_A  norm_labor_wedge  norm_labor_wedge-1  \
# 0       1906   2.195617   2.010602          4.414512            3.414512
# 1       1907   2.069769   3.666213          7.588215            6.588215
# 2       1908   2.017207   3.221243          6.497912            5.497912
# 3       1909   1.964193   2.835887          5.570229            4.570229
# 4       1910   2.154945   3.286629          7.082502            6.082502
# ..       ...        ...        ...               ...                 ...
# 39      1994   1.645863   1.265665          2.083111            1.083111
# 40      1995   1.738492   1.270087          2.208036            1.208036
# 41      1996   1.702936   1.233233          2.100117            1.100117
# 42      1997   1.753392   1.257845          2.205496            1.205496
# 43      1998   1.725733   1.214714          2.096272            1.096272
#
#     mu_M/mu_A_nom  mu_M/mu_A_real  norm_labor_wedge_nom  \
# 0             NaN             NaN                   NaN
# 1             NaN             NaN                   NaN
# 2             NaN             NaN                   NaN
# 3             NaN             NaN                   NaN
# 4             NaN             NaN                   NaN
# ..            ...             ...                   ...
# 39       1.070873        1.066738              1.762510
# 40       1.039593        1.050407              1.807324
# 41       1.035429        1.047524              1.763269
# 42       1.038223        1.047492              1.820412
# 43       1.051558        1.050234              1.814708
#
#     norm_labor_wedge_real  norm_labor_wedge-1_nom  norm_labor_wedge-1_real
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 2                     NaN                     NaN                      NaN
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      NaN
# ..                    ...                     ...                      ...
# 39               1.755704                0.762510                 0.755704
# 40               1.826125                0.807324                 0.826125
# 41               1.783866                0.763269                 0.783866
# 42               1.836664                0.820412                 0.836664
# 43               1.812423                0.814708                 0.812423
#
# [79 rows x 11 columns]

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'norm_labor_wedge-1', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'norm_labor_wedge-1',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Normalized labor wedge $\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1$}')
plt.savefig('../../Notes/comb_lab_w.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'norm_labor_wedge-1', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'norm_labor_wedge-1_real',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Normalized labor wedge $\tau_{W,t}$}')
plt.savefig('../../Notes/comb_lab_w.pdf')
plt.show()

# %%
df_merged
# Out:
#     year_wst  F_LM/F_LA  mu_M/mu_A  norm_labor_wedge  norm_labor_wedge-1  \
# 0       1906   2.195617   2.010602          4.414512            3.414512
# 1       1907   2.069769   3.666213          7.588215            6.588215
# 2       1908   2.017207   3.221243          6.497912            5.497912
# 3       1909   1.964193   2.835887          5.570229            4.570229
# 4       1910   2.154945   3.286629          7.082502            6.082502
# ..       ...        ...        ...               ...                 ...
# 39      1994   1.645863   1.265665          2.083111            1.083111
# 40      1995   1.738492   1.270087          2.208036            1.208036
# 41      1996   1.702936   1.233233          2.100117            1.100117
# 42      1997   1.753392   1.257845          2.205496            1.205496
# 43      1998   1.725733   1.214714          2.096272            1.096272
#
#     mu_M/mu_A_nom  mu_M/mu_A_real  norm_labor_wedge_nom  \
# 0             NaN             NaN                   NaN
# 1             NaN             NaN                   NaN
# 2             NaN             NaN                   NaN
# 3             NaN             NaN                   NaN
# 4             NaN             NaN                   NaN
# ..            ...             ...                   ...
# 39       1.070873        1.066738              1.762510
# 40       1.039593        1.050407              1.807324
# 41       1.035429        1.047524              1.763269
# 42       1.038223        1.047492              1.820412
# 43       1.051558        1.050234              1.814708
#
#     norm_labor_wedge_real  norm_labor_wedge-1_nom  norm_labor_wedge-1_real
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 2                     NaN                     NaN                      NaN
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      NaN
# ..                    ...                     ...                      ...
# 39               1.755704                0.762510                 0.755704
# 40               1.826125                0.807324                 0.826125
# 41               1.783866                0.763269                 0.783866
# 42               1.836664                0.820412                 0.836664
# 43               1.812423                0.814708                 0.812423
#
# [79 rows x 11 columns]

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_LM/F_LA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'F_LM/F_LA',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor productivity}')
plt.savefig('../../Notes/comb_lab_w.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'mu_M/mu_A', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'mu_M/mu_A_real',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Ratio of utility $\mu_M/\mu_A$}')
plt.savefig('../../Notes/comb_lab_w.pdf')
plt.show()
