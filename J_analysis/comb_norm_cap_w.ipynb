# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# import matplotlib as mpl
# # Use the pgf backend (must be set before pyplot imported)
# mpl.use('pgf')

# %%
df_pre = pd.read_csv('../../Data/Results/pre_cap_w.csv')
df_post = pd.read_csv('../../Data/Results/post_cap_w.csv')

# %%
df_merged = pd.concat([df_pre, df_post])

# %%
df_merged
# Out:
#     year_wst  F_KM/F_KA  mu_M/mu_A  norm_cap_wedge  norm_cap_wedge-1
# 0       1885  11.358560  -0.319194       -3.625584         -4.625584
# 1       1886   9.676428   0.477233        4.617908          3.617908
# 2       1887   9.419002   1.030904        9.710088          8.710088
# 3       1888   8.760942   0.935635        8.197047          7.197047
# 4       1889  10.631653   1.170439       12.443703         11.443703
# ..       ...        ...        ...             ...               ...
# 38      1993  22.203992   1.313157       29.157320         28.157320
# 39      1994  20.302986   1.265665       25.696779         24.696779
# 40      1995  21.543722   1.270087       27.362394         26.362394
# 41      1996  21.521398   1.233233       26.540903         25.540903
# 42      1997  22.214333   1.257845       27.942188         26.942188
#
# [96 rows x 5 columns]

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'norm_cap_wedge-1', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'norm_cap_wedge-1',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Normalized cap wedge $\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1$}')
plt.savefig('../../Notes/comb_cap_w.pgf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'norm_cap_wedge-1', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'norm_cap_wedge-1',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
#plt.title(r'\textbf{Normalized cap wedge $\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1$}')
plt.title(r'\textbf{Normalized cap wedge $\tau_{R,t}$}')
plt.savefig('../../Notes/comb_cap_w.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_KM/F_KA', 
#               label = r'Normalized cap wedge $\biggl(\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'F_KM/F_KA',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
#plt.title(r'\textbf{Normalized cap wedge $\frac{1 + \tau_{R,t}}{1 + \tau_{C,t}}-1$}')
plt.title(r'\textbf{Normalized cap wedge $\tau_{R,t}$}')
plt.savefig('../../Notes/comb_cap_w.pdf')
plt.show()
