# %%
# This is for checking the calibration of parameters

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_cns = pd.read_csv('../../Data/Downloaded_Old/pre_cns.csv')
df_emp = pd.read_csv('../../Data/Downloaded_Old/pre_emp.csv')
df_cap = pd.read_csv('../../Data/Downloaded_Old/pre_cap.csv')
df_GDP = pd.read_csv('../../Data/Downloaded_Old/pre_GDP.csv')

# %%
# parameters
α_KA  = 0.15
α_LA  = 0.55
α_KM  = 0.6
α_LM  = 0.4
η     = 0.15
γ_pre = 60
#γ_post = 76.4
γ_post = 68.8 
δ     = 0.05
β     = 0.96

# %%
# compute the share of gamma
df_cns['share_of_gamma'] = 50 / df_cns.food_cns

# %%
df_cns
# Out:
#     year_wst     tot_cns    food_cns  non_food_cns  share_of_gamma
# 0       1885   86.021602   58.446754     27.574848        0.855479
# 1       1886   90.521983   62.370821     28.151161        0.801657
# 2       1887   97.471067   65.767625     31.703442        0.760252
# 3       1888   98.178915   65.410468     32.768448        0.764404
# 4       1889  103.653760   67.473055     36.180704        0.741037
# 5       1890  100.128250   64.989906     35.138344        0.769350
# 6       1891  108.185226   70.679337     37.505890        0.707420
# 7       1892  105.950000   68.054221     37.895779        0.734708
# 8       1893  113.012558   73.612825     39.399732        0.679229
# 9       1894  109.726196   70.149811     39.576385        0.712760
# 10      1895  115.029335   72.803509     42.225826        0.686780
# 11      1896  118.287345   73.644831     44.642514        0.678934
# 12      1897  116.824620   72.733054     44.091567        0.687445
# ...

# %%
# choose gamma so that $\gamma$ is 87% of per-worker food consumption in 1885
food_cns_1885 = df_cns.loc[0, 'food_cns']

# %%
γ = food_cns_1885 * 0.87

# %%
γ
# Out:
# 50.84867618804961

# %%
50.85 / food_cns_1885
# Out:
# 0.8700226498796662
