# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# import matplotlib as mpl
# # Use the pgf backend (must be set before pyplot imported)
# mpl.use('pgf')

# %%
df_pre = pd.read_csv('../../Data/Results/pre_labor_w.csv')
df_post = pd.read_csv('../../Data/Results/post_labor_w.csv')

# %%
df_merged = pd.concat([df_pre, df_post])

# %%
df_merged.columns
# Out:
# Index(['year_wst', 'food', 'cons', 'non_food', 'food-PA_gammaA',
#        'PA_cA-gammaA/PM_cM', 'muM/PM/muA/PA', 'tot_emp', 'prm_emp', 'scn_emp',
#        'trt_emp', 'mil', 'non_prm_emp', 'prm_GDP', 'tot_GDP', 'non_prm_GDP',
#        'F_LA', 'F_LM', 'F_LM/F_LA', 'LM/LA', 'YM/YA', 'labor_wedge',
#        'year_jpn_x', 'pub_emp', 'year_jpn_y', 'tot_prv_GDP'],
#       dtype='object')

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'labor_wedge', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'labor_wedge',  
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor wedge $\tau_{W}$}')
#plt.savefig('../../Notes/Discussion/labor_w.pgf')
plt.savefig('../../Graphs/pdf/lab_w.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'YM/YA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'LM/LA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'c',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'YM/YA',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'LM/LA',  
               marker = '.',
               linestyle = '--',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L_M/L_A$ and output ratio $Y_M/Y_A$}')
#plt.savefig('../../Notes/Discussion/output_labor_ratio.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_LM/F_LA', 
#               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'F_LM/F_LA',  
               linestyle = '--',
               color = 'b',
               ax = ax)

#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor productivity ratio $P^{M}F^{M}_{L}/P^{A}F^{A}_{L}$}')
plt.savefig('../../Notes/Discussion/labor_prod_ratio.pgf')
#plt.savefig('../../Graphs/pdf/lab_prod_ratio.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_LM/F_LA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'muM/PM/muA/PA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               marker = '.',
               linestyle = '-.',
               color = 'c',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'F_LM/F_LA',  
               marker = '.',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 1975].plot(x = 'year_wst', y = 'muM/PM/muA/PA',  
               marker = '.',
               linestyle = '-.',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Normalized labor wedge $\tau_{W,t}$}')
#plt.savefig('../../Notes/comb_lab_w.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'YM/YA', 
               label = r'$P^{M}Y^{M}/P^{A}Y^{A}$', 
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'LM/LA', 
               label = r'$L^M/L^A$', 
               linestyle = '-.',
               color = 'c',
               ax = ax)

df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'YM/YA',  
               label = '_nolegend_',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'LM/LA',  
               label = '_nolegend_',
               linestyle = '-.',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
# ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L^M/L^A$ and output ratio $P^{M}Y^{M}/P^{A}Y^{A}$}')
plt.savefig('../../Notes/Discussion/output_labor_ratio.pgf')
plt.savefig('../../Graphs/pdf/output_lab_ratio.pdf')
plt.show()
# Out:
# /Users/satoshi/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:633: UserWarning: The handle <matplotlib.lines.Line2D object at 0x15d1c41f0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# /Users/satoshi/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:633: UserWarning: The handle <matplotlib.lines.Line2D object at 0x15d1b78b0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre[df_pre.year_wst >= 1920].plot(x = 'year_wst', y = 'YM/YA', 
               label = r'$P^{M}Y^{M}/P^{A}Y^{A}$', 
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre[df_pre.year_wst >= 1920].plot(x = 'year_wst', y = 'LM/LA', 
               label = r'$L^M/L^A$', 
               linestyle = '-.',
               color = 'c',
               ax = ax)

df_post[df_post.year_wst <= 1970].plot(x = 'year_wst', y = 'YM/YA',  
               label = '_nolegend_',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 1970].plot(x = 'year_wst', y = 'LM/LA',  
               label = '_nolegend_',
               linestyle = '-.',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
# ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L^M/L^A$ and output ratio $P^{M}Y^{M}/P^{A}Y^{A}$}')
plt.savefig('../../Notes/Discussion/output_labor_ratio.pgf')
#plt.savefig('../../Graphs/pdf/output_lab_ratio.pdf')
plt.show()
# Out:
# /Users/satoshi/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:633: UserWarning: The handle <matplotlib.lines.Line2D object at 0x15d38db80> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# /Users/satoshi/miniconda3/envs/jpandas/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:633: UserWarning: The handle <matplotlib.lines.Line2D object at 0x15ceff610> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'YM/YA', 
               label = r'$P^{M}Y^{M}/P^{A}Y^{A}$', 
               linestyle = '--',
               color = 'b',
               ax = ax)

df_pre.plot(x = 'year_wst', y = 'LM/LA', 
               label = r'$L^M/L^A$', 
               linestyle = '-.',
               color = 'c',
               ax = ax)

#df_post[df_post.year_wst <= 1980].plot(x = 'year_wst', y = 'YM/YA',  
#               label = '_nolegend_',
#               linestyle = '--',
#              color = 'b',
#               ax = ax)

#df_post[df_post.year_wst <= 1980].plot(x = 'year_wst', y = 'LM/LA',  
#               label = '_nolegend_',
#               linestyle = '-.',
#               color = 'c',
#               ax = ax)
#ax.set_rasterized(True)
#ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L^M/L^A$ and output ratio $P^{M}Y^{M}/P^{A}Y^{A}$}')
plt.savefig('../../Notes/Discussion/output_labor_ratio.pgf')
plt.savefig('../../Graphs/pdf/output_lab_ratio_pre.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
#df_pre.plot(x = 'year_wst', y = 'YM/YA', 
#               label = r'$Y_M/Y_A$', 
#               linestyle = '--',
#               color = 'b',
#               ax = ax)

#df_pre.plot(x = 'year_wst', y = 'LM/LA', 
#               label = r'$L_M/L_A$', 
#               linestyle = '-.',
#               color = 'c',
#               ax = ax)

df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'YM/YA',  
               label = '$P^{M}Y^{M}/P^{A}Y^{A}$',
               linestyle = '--',
               color = 'b',
               ax = ax)

df_post[df_post.year_wst <= 2000].plot(x = 'year_wst', y = 'LM/LA',  
               label = '$L_M/L_A$',
               linestyle = '-.',
               color = 'c',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor ratio $L_M/L_A$ and output ratio $P^{M}Y^{M}/P^{A}Y^{A}$}')
plt.savefig('../../Notes/Discussion/output_labor_ratio_post.pgf')
#plt.savefig('../../Graphs/pdf/output_lab_ratio_post.pdf')
plt.show()

# %%
df_pre[['year_wst', 'LM/LA', 'YM/YA']]
# Out:
#     year_wst     LM/LA     YM/YA
# 0       1906  0.603309  2.142793
# 1       1907  0.613407  2.053782
# 2       1908  0.625518  2.041147
# 3       1909  0.638984  2.030290
# 4       1910  0.641886  2.237576
# 5       1911  0.642278  2.205401
# 6       1912  0.646964  2.331693
# 7       1913  0.655707  2.329160
# 8       1914  0.657198  1.945448
# 9       1915  0.721167  2.253066
# 10      1916  0.737627  2.439198
# 11      1917  0.743718  2.656784
# 12      1918  0.814304  2.815495
# 13      1919  0.811505  2.889111
# 14      1920  0.830781  2.664879
# 15      1921  0.846053  3.522094
# 16      1922  0.867518  3.394489
# 17      1923  0.969045  3.519761
# 18      1924  0.922410  3.522555
# 19      1925  0.952946  3.302850
# 20      1926  0.969529  3.691482
# 21      1927  0.955034  3.446375
# 22      1928  0.960902  3.883555
# 23      1929  0.972779  3.980550
# 24      1930  0.994009  3.397444
# 25      1931  0.993856  4.024620
# 26      1932  1.063839  3.879299
# ...

# %%
df_pre[df_pre.year_wst >= 1935].loc[:,'YM/YA'].mean()
# Out:
# 5.167251645961408

# %%
df_pre[df_pre.year_wst >= 1935].loc[:,'LM/LA'].mean()
# Out:
# 1.157830704886502

# %%
df_pre[df_pre.year_wst >= 1930].loc[:,'YM/YA'].mean() / df_pre[df_pre.year_wst >= 1930].loc[:,'LM/LA'].mean()
# Out:
# 4.192912021041323

# %%
df_post[(df_post.year_wst > 1955 ) & (df_post.year_wst <= 1960)].loc[:,'YM/YA'].mean()
# Out:
# 4.612596937566406

# %%
df_post[df_post.year_wst <= 1960].loc[:,'LM/LA'].mean()
# Out:
# 1.895086479680734

# %%
df_post[df_post.year_wst <= 1960].loc[:,'YM/YA'].mean() / df_post[df_post.year_wst <= 1960].loc[:,'LM/LA'].mean()
# Out:
# 2.351700669395697

# %%
df_post[df_post.year_wst <= 1970].loc[:,'YM/YA'].mean() / df_post[df_post.year_wst <= 1970].loc[:,'LM/LA'].mean()
# Out:
# 2.7373808481149853

# %%
8.125938/3.677072
# Out:
# 2.2098936327599787

# %%
3.106918/1.577474
# Out:
# 1.9695525885054206

# %%
18.799859/8.774442
# Out:
# 2.142570319571319

# %%
df_post[['year_wst', 'LM/LA', 'YM/YA', 'F_LM/F_LA']]
# Out:
#     year_wst      LM/LA      YM/YA  F_LM/F_LA
# 0       1955   1.577474   3.677072   1.440974
# 1       1956   1.692667   4.152500   1.516542
# 2       1957   1.830948   4.437809   1.498335
# 3       1958   1.957386   4.619742   1.459007
# 4       1959   2.107567   4.655759   1.365606
# 5       1960   2.204478   5.197174   1.457397
# 6       1961   2.336147   5.666902   1.499553
# 7       1962   2.475927   6.134565   1.531659
# 8       1963   2.713568   6.971105   1.588098
# 9       1964   2.910357   7.631510   1.620990
# 10      1965   3.106918   8.125938   1.616813
# 11      1966   3.358209   8.774442   1.615206
# 12      1967   3.597490   9.861827   1.694626
# 13      1968   3.901822  11.657684   1.846975
# 14      1969   4.157505  13.453564   2.000418
# 15      1970   4.558691  16.760689   2.272835
# 16      1971   5.071166  18.799859   2.291728
# 17      1972   5.547020  18.084822   2.015444
# 18      1973   6.188652  18.392997   1.837269
# ...

# %%
df_merged
# Out:
#     year_wst           food          cons       non_food  food-PA_gammaA  \
# 0       1906      66.250000  1.132900e+02      47.040000       15.400000
# 1       1907      67.460000  1.150500e+02      47.590000       16.610000
# 2       1908      77.030000  1.271500e+02      50.120000       26.180000
# 3       1909      75.200000  1.279500e+02      52.750000       24.350000
# 4       1910      78.950000  1.316000e+02      52.650000       28.100000
# ..       ...            ...           ...            ...             ...
# 39      1994  259232.479485  1.082051e+06  822818.851249   154041.620858
# 40      1995  257590.661803  1.084284e+06  826693.183370   152399.803177
# 41      1996  261160.871913  1.109536e+06  848375.182108   155970.013287
# 42      1997  260793.236507  1.107196e+06  846402.450263   155602.377880
# 43      1998  258871.837218  1.092648e+06  833776.642196   153680.978591
#
#     PA_cA-gammaA/PM_cM  muM/PM/muA/PA   tot_emp   prm_emp  scn_emp  ...  \
# ...

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'F_LM/F_LA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$', 
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'F_LM/F_LA',  
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Labor productivity}')
#plt.savefig('../../Notes/labor_prod_ratio.pdf')
#plt.savefig('../../Graphs/pdf/lab_prod_ratio.pdf')
plt.show()

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'muM/PM/muA/PA', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'muM/PM/muA/PA',  
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Ratio of expenditures $P_AC_A/P_MC_M$}')
#plt.savefig('../../Notes/exp.pdf')
plt.show()

# %%
df_pre['prm_emp_share'] = df_pre.prm_emp / df_pre.tot_emp

# %%
df_post['prm_emp_share'] = df_post.prm_emp / df_post.tot_emp

# %%
fig, ax = plt.subplots()

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#plt.rc('pgf', texsystem = 'xelatex')
df_pre.plot(x = 'year_wst', y = 'prm_emp_share', 
               label = r'Normalized labor wedge $\biggl(\frac{1 + \tau_{W,t}}{1 + \tau_{C,t}}-1 \biggr)$',
               linestyle = '--',
               color = 'b',
               ax = ax)
df_post.plot(x = 'year_wst', y = 'prm_emp_share',  
               linestyle = '--',
               color = 'b',
               ax = ax)
#ax.set_rasterized(True)
ax.legend_.remove()
plt.xlabel('year')
fig.set_size_inches(w=6.26894, h=3.5)
plt.title(r'\textbf{Employment share of agriculture}')
plt.savefig('../../Notes/Discussion/prm_emp_share.pgf')
plt.show()

# %%
df_pre[['year_wst', 'prm_emp_share']]
# Out:
#     year_wst  prm_emp_share
# 0       1906       0.617533
# 1       1907       0.616113
# 2       1908       0.611405
# 3       1909       0.606715
# 4       1910       0.605914
# 5       1911       0.605884
# 6       1912       0.604212
# 7       1913       0.601387
# 8       1914       0.600888
# 9       1915       0.578486
# 10      1916       0.573144
# 11      1917       0.570570
# 12      1918       0.545985
# 13      1919       0.546849
# 14      1920       0.541202
# 15      1921       0.538804
# 16      1922       0.532602
# 17      1923       0.505514
# 18      1924       0.515930
# 19      1925       0.508150
# 20      1926       0.504479
# 21      1927       0.506433
# 22      1928       0.505612
# 23      1929       0.502318
# 24      1930       0.497032
# 25      1931       0.496112
# 26      1932       0.463435
# 27      1933       0.457525
# 28      1934       0.481629
# 29      1935       0.473966
# 30      1936       0.471512
# 31      1937       0.459614
# ...

# %%
df_post[['year_wst', 'prm_emp_share']]
# Out:
#     year_wst  prm_emp_share
# 0       1955       0.375550
# 1       1956       0.359626
# 2       1957       0.342677
# 3       1958       0.327594
# 4       1959       0.310957
# 5       1960       0.302074
# 6       1961       0.289684
# 7       1962       0.278095
# 8       1963       0.259848
# 9       1964       0.246831
# 10      1965       0.235307
# 11      1966       0.222084
# 12      1967       0.210569
# 13      1968       0.197521
# 14      1969       0.187698
# 15      1970       0.173930
# 16      1971       0.159149
# 17      1972       0.147288
# 18      1973       0.134056
# 19      1974       0.128891
# 20      1975       0.126556
# 21      1976       0.121988
# 22      1977       0.118682
# 23      1978       0.117049
# 24      1979       0.111882
# 25      1980       0.104227
# 26      1981       0.099803
# 27      1982       0.097198
# 28      1983       0.092622
# 29      1984       0.088796
# 30      1985       0.087653
# 31      1986       0.084572
# ...

# %%
df_post[df_post.year_wst < 1960].loc[:,'prm_emp_share'].mean()
# Out:
# 0.3432809219680869
