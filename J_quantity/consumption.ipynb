# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
url = "https://d-infra.ier.hit-u.ac.jp/Japanese/ltes/LTES_06_01.xlsx"

# %%
xl = pd.ExcelFile(url)

# %%
xl.sheet_names
# Out:
# ['第1表',
#  '第2表',
#  '第3表',
#  '第4表',
#  '第5表',
#  '第6表',
#  '第7表',
#  '第8表',
#  '第9表',
#  '第10表',
#  '第11表',
#  '第12表',
#  '第13表',
#  '第14表',
#  '第15表',
#  '第16表',
#  '第17表',
#  '第18表',
#  '第19表',
#  '第20表',
#  '第21表',
#  '第22表',
#  '第23表',
#  '第24表',
#  '第25表',
#  '第26表',
#  '第27表',
#  '第28表',
#  '第29表',
#  '第30表',
#  '第31表']

# %%
df_original = xl.parse('第1表')

# %%
df_original
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  \
# 0          NaN         NaN        NaN
# 1          NaN         NaN        NaN
# 2          NaN         NaN        NaN
# 3          NaN         NaN        NaN
# 4          NaN         NaN        NaN
# ..         ...         ...        ...
# 76         NaN         NaN       1936
# 77         NaN         NaN       1937
# 78         NaN         NaN       1938
# 79         NaN         NaN       1939
# 80         NaN         NaN       1940
#
#                                            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                          第1表　個人消費支出（当年価格，1874～1940）        NaN        NaN
# 1   Table 1　Personal Consumption Expenditures in C...        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4                                               48293      48294      48295
# ..                                                ...        ...        ...
# 76                                            6894026    1879465    1647561
# 77                                            7522214    2471387    1786841
# 78                                            8113751    3089420    1937679
# 79                                            9129037    1915388    2122199
# 80                                            9955110    2246723    2655686
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0         NaN        NaN        NaN        NaN         NaN         NaN
# 1         NaN        NaN        NaN        NaN         NaN         NaN
# 2         NaN        NaN        NaN        NaN         NaN         NaN
# 3         NaN        NaN        NaN        NaN         NaN         NaN
# 4       48296      48297      48298      48299       48300       48301
# ..        ...        ...        ...        ...         ...         ...
# 76     578710     717902     447689      93213      375950     1087512
# 77     648158     869082     486287     108984      408800     1281159
# 78     755718     990118     559356     115418      449680     1424562
# 79     792375    1071134     701692     121852      544580     1515240
# 80     915604    1159019     837634     129163      730000     1727993
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4        48302
# ..         ...
# 76    13722028
# 77    15582912
# 78    17435702
# 79    17913497
# 80    20356932
#
# [81 rows x 13 columns]

# %%
stat_name_jpn = df_original.iloc[0,3]

# %%
stat_name_jpn
# Out:
# '第1表\u3000個人消費支出（当年価格，1874～1940）'

# %%
stat_name_eng = df_original.iloc[1,3]

# %%
stat_name_eng
# Out:
# 'Table 1\u3000Personal Consumption Expenditures in Current Prices, 1874～1940'

# %%
# Remove columns and rows with too many nulls
df_dropped = df_original.loc[df_original.notnull().sum(axis=1) > 2, df_original.notnull().sum() > 2]

# %%
df_dropped
# Out:
#    Unnamed: 2                                         Unnamed: 3  \
# 4         NaN                                              48293
# 5         NaN                                                  1
# 6         NaN                                         個人消費支出：食料費
# 7         NaN  Personal Consumption Expenditures in Current P...
# 8         NaN                                         J0601__001
# ..        ...                                                ...
# 76       1936                                            6894026
# 77       1937                                            7522214
# 78       1938                                            8113751
# 79       1939                                            9129037
# 80       1940                                            9955110
#
#                                            Unnamed: 4  \
# 4                                               48294
# 5                                                   1
# 6                                          個人消費支出：被服費
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__002
# ..                                                ...
# 76                                            1879465
# 77                                            2471387
# 78                                            3089420
# 79                                            1915388
# 80                                            2246723
#
#                                            Unnamed: 5  \
# 4                                               48295
# 5                                                   1
# 6                                          個人消費支出：住居費
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__003
# ..                                                ...
# 76                                            1647561
# 77                                            1786841
# 78                                            1937679
# 79                                            2122199
# 80                                            2655686
#
#                                            Unnamed: 6  \
# 4                                               48296
# 5                                                   1
# 6                                          個人消費支出：光熱費
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__004
# ..                                                ...
# 76                                             578710
# 77                                             648158
# 78                                             755718
# 79                                             792375
# 80                                             915604
#
#                                            Unnamed: 7  \
# 4                                               48297
# 5                                                   1
# 6                                        個人消費支出：保健衛生費
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__005
# ..                                                ...
# 76                                             717902
# 77                                             869082
# 78                                             990118
# 79                                            1071134
# 80                                            1159019
#
#                                            Unnamed: 8  \
# 4                                               48298
# 5                                                   1
# 6                                          個人消費支出：交通費
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__006
# ..                                                ...
# 76                                             447689
# 77                                             486287
# 78                                             559356
# 79                                             701692
# 80                                             837634
#
#                                            Unnamed: 9  \
# 4                                               48299
# 5                                                   1
# 6                                          個人消費支出：通信費
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__007
# ..                                                ...
# 76                                              93213
# 77                                             108984
# 78                                             115418
# 79                                             121852
# 80                                             129163
#
#                                           Unnamed: 10  \
# 4                                               48300
# 5                                                   1
# 6                                          個人消費支出：交際費
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__008
# ..                                                ...
# 76                                             375950
# 77                                             408800
# 78                                             449680
# 79                                             544580
# 80                                             730000
#
#                                           Unnamed: 11  \
# 4                                               48301
# 5                                                   1
# 6                                    個人消費支出：教養娯楽費，その他
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__009
# ..                                                ...
# 76                                            1087512
# 77                                            1281159
# 78                                            1424562
# 79                                            1515240
# 80                                            1727993
#
#                                           Unnamed: 12
# 4                                               48302
# 5                                                   1
# 6                                            個人消費支出：計
# 7   Personal Consumption Expenditures in Current P...
# 8                                          J0601__010
# ..                                                ...
# 76                                           13722028
# 77                                           15582912
# 78                                           17435702
# 79                                           17913497
# 80                                           20356932
#
# [77 rows x 11 columns]

# %%
# save units

# %%
food_unit_jpn = df_dropped.iloc[8,2]

# %%
food_unit_eng = df_dropped.iloc[9,2]

# %%
total_unit_jpn = df_dropped.iloc[8, -1]
total_unit_eng = df_dropped.iloc[9, -1]

# %%
# Notice the difference
food_unit_jpn, total_unit_jpn
# Out:
# ('1000円:N', '1000円:N')

# %%
# Pick food consumption and total consumption
df_picked = df_dropped.iloc[10:,[0, 1, -1]]

# %%
df_picked.columns = ['year_wst', 'food', 'total']

# %%
df_picked
# Out:
#    year_wst     food     total
# 14     1874   267129    417462
# 15     1875   332326    504638
# 16     1876   294629    454628
# 17     1877   314203    477924
# 18     1878   341480    521839
# ..      ...      ...       ...
# 76     1936  6894026  13722028
# 77     1937  7522214  15582912
# 78     1938  8113751  17435702
# 79     1939  9129037  17913497
# 80     1940  9955110  20356932
#
# [67 rows x 3 columns]
